# %%
# !python 01_prepare_dataset.py

# %%
# %cd scraping/batch_api/

# %%
# !python 00_prepare_dataset.py

# %%
# %cd ~/git/balanced-plms/
# Out:
# /home/vejvar-martin-nj/git/balanced-plms

# %%
# !python main_batch_api.py "prepare_arrow_dataset" --input-file scraping/batch_api/sparql_explain_data.jsonl --output-dir /work/datasets/sparql_explain_arrow
# Out:
# Using `32` processors.
# Counting tokens: 100%|███████| 1921535/1921535 [09:58<00:00, 3209.91 examples/s]
# Counting tokens: 100%|█████████████████| 41/41 [00:00<00:00, 2379.63 examples/s]
# Train grouped dataset: blocks=1921535, tokens=983825920
# Dev grouped dataset: blocks=41, tokens=20992
# Saving the dataset (10/10 shards): 100%|█| 1921535/1921535 [00:05<00:00, 346613.
# Saving the dataset (1/1 shards): 100%|█| 41/41 [00:00<00:00, 10310.98 examples/s
# Saved train dataset to /work/datasets/sparql_explain_arrow/grouped
# Saved dev dataset to /work/datasets/sparql_explain_arrow/shared_dev_grouped/grouped

# %%
# %cd pretraining/
# Out:
# /home/vejvar-martin-nj/git/balanced-plms/pretraining

# %%
# !python 03_inject_sparql.py  --output-dir /work/datasets/openwebtext-injected-SPARQL-30p --proportion 0.3
# Out:
# Loading OpenWebText from /work/datasets/openwebtext-preproc/final_clean_grouped
# Loading dataset from disk: 100%|███████████████| 31/31 [00:00<00:00, 279.96it/s]
# Loading SPARQL dataset from /work/datasets/sparql_explain_arrow/grouped
# OWT blocks: 5842779, SPARQL blocks: 1921535
# Replacing 1752833 blocks (30% of OWT)
# {'num_replaced': 1752833, 'num_kept': 4089946, 'num_injected': 1752833, 'total_after_injection': 5842779}
# Saving the dataset (31/31 shards): 100%|█| 5842779/5842779 [01:33<00:00, 62761.4
# Saving the dataset (1/1 shards): 100%|█| 23248/23248 [00:00<00:00, 317478.83 exa
# Saved merged dataset to /work/datasets/openwebtext-injected-SPARQL-30p/final_clean_grouped
