# %%
# !python 01_prepare_dataset.py

# %%
# %cd scraping/batch_api/

# %%
# !python 00_prepare_dataset.py

# %%
# %cd ~/git/balanced-plms/
# Out:
# /home/vejvar-martin-nj/git/balanced-plms

# %%
# !python main_batch_api.py "prepare_arrow_dataset" --input-file scraping/batch_api/sparql_explain_data.jsonl --output-dir /work/datasets/sparql_explain_arrow
# Out:
# Using `32` processors.

# %%
# !python 05_prepare_arrow_dataset.py --input-file scraping/batch_api/sparql_explain_data.jsonl --output-dir /work/datasets/sparql_explain_arrow
# Out:
# python: can't open file '/home/vejvar-martin-nj/git/balanced-plms/05_prepare_arrow_dataset.py': [Errno 2] No such file or directory

# %%
# %cd pretraining/
# Out:
# /home/vejvar-martin-nj/git/balanced-plms/pretraining

# %%
# !python 03_inject_sparql.py
# Out:
# Loading OpenWebText from /work/datasets/openwebtext-preproc/final_clean_grouped
# Loading dataset from disk: 100%|███████████████| 31/31 [00:00<00:00, 165.30it/s]
# Loading SPARQL dataset from /work/datasets/sparql_explain_arrow/grouped
# OWT blocks: 5842779, SPARQL blocks: 258932
# Replacing 584277 blocks (10% of OWT)
# Num replaced samples: 584277
# Num kept samples: `5258502`
# Num injected samples: `584277`.
# Total samples after injection: `5842779`
# Saving the dataset (31/31 shards): 100%|█| 5842779/5842779 [01:27<00:00, 66612.8
# Saving the dataset (1/1 shards): 100%|█| 23248/23248 [00:00<00:00, 198707.97 exa
# Saved merged dataset to /work/datasets/openwebtext-injected-SPARQL-10p/final_clean_grouped
